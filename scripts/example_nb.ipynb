# %%
from viz import plot_snapshots

from project import load_config, solve_heat_equation

# %%
cfg = load_config("../config.yaml")

# %%
x, y, t, T_fdm = solve_heat_equation(cfg)

# %%
plot_snapshots(
    x,
    y,
    t,
    T_fdm,
    title="FDM Solution",
    show_interactively=True,
)
